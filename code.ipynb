# %%
# Initialisation de la base de données des plats
menu = [
    {"id": 1, "nom": "Soupe à l'oignon", "prix": 8.50, "allergenes": ["Gluten", "Lactose"], "categ": "Entrée"},
    {"id": 2, "nom": "Escargots de Bourgogne", "prix": 10.00, "allergenes": ["Lactose"], "categ": "Entrée"},
    {"id": 3, "nom": "Foie Gras", "prix": 14.50, "allergenes": [], "categ": "Entrée"},
    {"id": 4, "nom": "Boeuf Bourguignon", "prix": 18.50, "allergenes": ["Sulfites"], "categ": "Plat"},
    {"id": 5, "nom": "Coq au Vin", "prix": 17.00, "allergenes": ["Sulfites", "Gluten"], "categ": "Plat"},
    {"id": 6, "nom": "Ratatouille", "prix": 14.00, "allergenes": [], "categ": "Plat"},
    {"id": 7, "nom": "Steak Frites", "prix": 16.50, "allergenes": [], "categ": "Plat"},
    {"id": 8, "nom": "Crème Brûlée", "prix": 7.00, "allergenes": ["Lactose", "Oeuf"], "categ": "Dessert"},
    {"id": 9, "nom": "Tarte Tatin", "prix": 8.00, "allergenes": ["Gluten", "Lactose"], "categ": "Dessert"},
    {"id": 10, "nom": "Mousse au Chocolat", "prix": 6.50, "allergenes": ["Oeuf", "Lactose"], "categ": "Dessert"}
]

#Initialisation de valeur

nom_restaurant = "Au Bon Terroir"
nom_restaurant_large = """
      ██                    ▀███▀▀▀██▄                       ███▀▀██▀▀███                                  ██          
     ▄██▄                     ██    ██                       █▀   ██   ▀█                                              
    ▄█▀██▄   ▀███  ▀███       ██    ██ ▄██▀██▄▀████████▄          ██      ▄▄█▀██▀███▄███▀███▄███  ▄██▀██▄▀███ ▀███▄███ 
   ▄█  ▀██     ██    ██       ██▀▀▀█▄▄██▀   ▀██ ██    ██          ██     ▄█▀   ██ ██▀ ▀▀  ██▀ ▀▀ ██▀   ▀██ ██   ██▀ ▀▀ 
   ████████    ██    ██       ██    ▀███     ██ ██    ██          ██     ██▀▀▀▀▀▀ ██      ██     ██     ██ ██   ██     
  █▀      ██   ██    ██       ██    ▄███▄   ▄██ ██    ██          ██     ██▄    ▄ ██      ██     ██▄   ▄██ ██   ██     
▄███▄   ▄████▄ ▀████▀███▄   ▄████████  ▀█████▀▄████  ████▄      ▄████▄    ▀█████▀████▄  ▄████▄    ▀█████▀▄████▄████▄"""
selecteur_choix = """
+----------------------------------+
|                                  |
|      Selectionnez un rôle :      |
|      1: Restaurateur             |
|      2: Consommateur             |
|                                  |
+----------------------------------+"""

# %%
def consommateur():

# %%
def restaurateur():
    pass

# %%
#Menu

#Choix du role1
1

def choixMenu():
    print(nom_restaurant_large)
    while True:
        choix = int(input(selecteur_choix))
        if choix == 1:
            restaurateur()
        elif choix == 2:
            consommateur()
        else:
            print("Saissisez un bon choix")

# %%
#Execution de demarrage du programme

choixMenu()
# Out:
#       ██                    ▀███▀▀▀██▄                       ███▀▀██▀▀███                                  ██
#      ▄██▄                     ██    ██                       █▀   ██   ▀█
#     ▄█▀██▄   ▀███  ▀███       ██    ██ ▄██▀██▄▀████████▄          ██      ▄▄█▀██▀███▄███▀███▄███  ▄██▀██▄▀███ ▀███▄███
#    ▄█  ▀██     ██    ██       ██▀▀▀█▄▄██▀   ▀██ ██    ██          ██     ▄█▀   ██ ██▀ ▀▀  ██▀ ▀▀ ██▀   ▀██ ██   ██▀ ▀▀
#    ████████    ██    ██       ██    ▀███     ██ ██    ██          ██     ██▀▀▀▀▀▀ ██      ██     ██     ██ ██   ██
#   █▀      ██   ██    ██       ██    ▄███▄   ▄██ ██    ██          ██     ██▄    ▄ ██      ██     ██▄   ▄██ ██   ██
# ▄███▄   ▄████▄ ▀████▀███▄   ▄████████  ▀█████▀▄████  ████▄      ▄████▄    ▀█████▀████▄  ▄████▄    ▀█████▀▄████▄████▄
# Saissisez un bon choix
# Saissisez un bon choix
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...
