# %%
def restaurateur():
    pass

# %%
def consommateur():
    pass

# %%
#Menu

#Choix du role
def choixMenu():
    while True:
        choix = int(input("Choix un rôle : \n1: Restaurateur \n2: Consommateur\n >"))
        if choix == 1:
            restaurateur()
        elif choix == 2:
            consommateur()
        else:
            print("Saissisez un bon choix")
